# %%
# %matplotlib notebook
import nibabel as nib
import matplotlib.pyplot as plt


image_t1 = nib.load("../small_data/small/t1/IXI104-HH-1450-T1_fcm.nii.gz").get_fdata()
image_t2 = nib.load("../small_data/small/t2/IXI104-HH-1450-T2_reg_fcm.nii.gz").get_fdata()

# %%
fig, axis = plt.subplots(1, 2, figsize=(9, 5))
axis[0].imshow(image_t1[:,40,:], cmap="gray")
axis[0].set_title("T1")
axis[1].imshow(image_t2[:,40,:], cmap="gray")
axis[1].set_title("T2")
# Out:
# <img src="data:image/png;base64,..." width="900">
# Text(0.5, 1.0, 'T2')
